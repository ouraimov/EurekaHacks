# %%
import pandas as pd
import numpy as np
import matplotlib as plot

# %%
data = pd.read_csv("addon_edit_final.csv")

# %%
web = pd.read_csv("web_visits.csv")

# %%
data
# Out:
#               SKU                                Product Description  \
# 0      RAW-DO-001                Donate $1 to Right Action for Women
# 1      SPO-BE-007                Spongelle Freesia Pear Boxed Flower
# 2      DPH-BE-012               dpHUE Apple Cider Vinegar Hair Rinse
# 3      BLA-BE-002  Blaq Hydrogel Eye Mask with Hyaluronic Acid (5...
# 4      DRB-BE-013                Dr. brandt Triple Peptide Eye Cream
# 5     CALL-BE-001    Callysee Buffing Beans Coffee Scrub Deluxe Size
# 6      DAI-BE-010         Daily Concepts Body Towel Wrap in Poly Bag
# 7      BEN-LI-002                 Bentgo Original Lunchbox in Purple
# 8      DRB-BE-001                       Dr. Brandt Microdermabrasion
# 9      BLA-BE-006                        Blaq Teeth Whitening Powder
# 10     BRI-BE-001                               Briogeo Rosarco Milk
# 11     AQU-BE-002          AQUIS Luxe Lisse Hair Towel – Desert Rose
# 12     LAM-BE-001                      Lashes MD Eyelash Conditioner
# ...

# %%
web.sort_values(by="num_visits", ascending=False)
# Out:
#       year  season    Type                                       product_name  \
# 1017  2018  winter  Add-On                          homemade-ayesha-curry-mug
# 0     2019  spring  Add-On             fabfitfun-spring-2019-collectible-tote
# 1018  2018  winter  Add-On                                 fabfitfun-mens-box
# 1019  2018  winter  Add-On                                     girls-night-in
# 1020  2018  winter  Add-On                                  all-that-glitters
# 1397  2019  winter    Edit                       elemis-winter-collection-kit
# 1     2019  spring  Add-On  coconut-oil-ylang-ylang-love-beauty-planet-deo...
# 1398  2019  winter    Edit                                   whip-hair-bundle
# 1021  2018  winter  Add-On                               cylo-tech-junkie-kit
# 2     2019  spring  Add-On                                sand-cloud-xl-towel
# 442   2018    fall  Add-On                aimee-kestenberg-hanging-makeup-bag
# ...

# %%
data = data.sort_values(by="Cart Items", ascending = False)

# %%
data
# Out:
#               SKU                                Product Description  \
# 268    SUM-FA-104                 Summer & Rose Crossbody - Burgundy
# 2509   JUN-LI-005                            FreshETech Bag Resealer
# 1335   TAR-BE-042                  tarte tarteist™ lip crayon - boho
# 2508   SUM-FA-014          Summer & Rose Round cross body bag in tan
# 1336   PUC-BE-002                                 PUR In The Clear
# 957    ORI-BE-007             Oribe Daily Ritual Cream Face Cleanser
# 1337   NAT-TE-002  Native Union Smart Hub Charger in Exclusive White
# 613    LOL-BE-001              Lollia Breathe Shea Butter Hand Creme
# 612    TCG-BE-001  The Cottage Greenhouse Sugar Beet and Blossom ...
# 1988   MAE-BE-001                           MaeLove Glow Maker Serum
# 1339   MAE-BE-001                           MaeLove Glow Maker Serum
# 1338   SAN-LI-002                        Sand Cloud XL Towel (black)
# 1989   LIV-BE-016  Living Proof Perfect hair Day 5-in-1 Styling T...
# ...
