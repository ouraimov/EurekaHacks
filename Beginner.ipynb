# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import descartes
import geopandas as gpd
from shapely.geometry import Point, Polygon

# %matplotlib inline

# %%
data = pd.read_csv("hourly_42101_2018.csv", low_memory=False)

# %%
data
# Out:
#          State Code  County Code  Site Num  Parameter Code  POC   Latitude  \
# 0                 1           73        23           42101    2  33.553056
# 1                 1           73        23           42101    2  33.553056
# 2                 1           73        23           42101    2  33.553056
# 3                 1           73        23           42101    2  33.553056
# 4                 1           73        23           42101    2  33.553056
# 5                 1           73        23           42101    2  33.553056
# 6                 1           73        23           42101    2  33.553056
# 7                 1           73        23           42101    2  33.553056
# 8                 1           73        23           42101    2  33.553056
# 9                 1           73        23           42101    2  33.553056
# 10                1           73        23           42101    2  33.553056
# ...

# %%
is_LA = data['County Name']== "Los Angeles"

# %%
data_LA = data[is_LA]

# %%
data_LA
# Out:
#         State Code  County Code  Site Num  Parameter Code  POC   Latitude  \
# 174873           6           37         2           42101    1  34.136500
# 174874           6           37         2           42101    1  34.136500
# 174875           6           37         2           42101    1  34.136500
# 174876           6           37         2           42101    1  34.136500
# 174877           6           37         2           42101    1  34.136500
# 174878           6           37         2           42101    1  34.136500
# 174879           6           37         2           42101    1  34.136500
# 174880           6           37         2           42101    1  34.136500
# 174881           6           37         2           42101    1  34.136500
# 174882           6           37         2           42101    1  34.136500
# 174883           6           37         2           42101    1  34.136500
# 174884           6           37         2           42101    1  34.136500
# ...

# %%
data_LA.size
# Out:
# 1375896

# %%
LA1 = (data_LA.groupby(["Site Num"]).size()).to_frame()

# %%
crs = {'init':'epsg:4326'}

# %%
geometry = [Point(xy) for xy in zip(data_LA["Longitude"], data_LA["Latitude"])]

# %%
geometry[:3]

# %%
geo_df = gpd.GeoDataFrame(data_LA, crs = crs, geometry = geometry)
street_map = gpd.read_file("CAMS_ZIPCODE_STREET_SPECIFIC.shp")

# %%
fig,ax = plt.subplots(figsize = (15,15))
street_map.plot(ax=ax)

# %%
street_map
# Out:
#      OBJECTID_1  OBJECTID  FID_1   Name  SDE_STATE_  ORIG_FID  Distance  \
# 0             1       105      0  90001         0.0      8499       0.0
# 1             2       194      1  90004         0.0      8502       0.0
# 2             3       157      2  90006         0.0      8504       0.0
# 3             4       136      3  90007         0.0      8505       0.0
# 4             5       122      4  90008         0.0      8506       0.0
# 5             6       175      5  90010         0.0      8507       0.0
# 6             7       130      6  90011         0.0      8508       0.0
# 7             8       202      7  90012         0.0      8509       0.0
# 8             9       154      8  90013         0.0      8510       0.0
# 9            10       148      9  90014         0.0      8511       0.0
# 10           11       152     10  90015         0.0      8512       0.0
# 11           12       162     11  90017         0.0      8514       0.0
# ...
